# %%
import pandas as pd

# %%
df=pd.read_csv("UpdatedResumeDataSet.csv")

# %%
df.head()
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...

# %%
df.tail()
# Out:
#     Category                                             Resume
# 957  Testing  Computer Skills: â¢ Proficient in MS office (...
# 958  Testing  â Willingness to accept the challenges. â ...
# 959  Testing  PERSONAL SKILLS â¢ Quick learner, â¢ Eagerne...
# 960  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 961  Testing  Skill Set OS Windows XP/7/8/8.1/10 Database MY...

# %%
df['Category'].value_counts()
# Out:
# Category
# Java Developer               84
# Testing                      70
# DevOps Engineer              55
# Python Developer             48
# Web Designing                45
# HR                           44
# Hadoop                       42
# Blockchain                   40
# ETL Developer                40
# Operations Manager           40
# Data Science                 40
# Sales                        40
# Mechanical Engineer          40
# Arts                         36
# Database                     33
# Electrical Engineering       30
# Health and fitness           30
# PMO                          30
# Business Analyst             28
# DotNet Developer             28
# Automation Testing           26
# Network Security Engineer    25
# SAP Developer                24
# Civil Engineer               24
# Advocate                     20
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Category    0
# Resume      0
# dtype: int64

# %%
import re
def preprocess(text):
    text = re.sub(r'[^\w\s]',' ', text)
    text = re.sub(' +', ' ', text)
    text = re.sub(r'[\r\n]+', ' ', text)
    text = re.sub(r'[^\x00-\x7F]+', '', text)
    return text.strip().lower()

# %%
df['cleaned_resume_data'] = df['Resume'].map(preprocess)

# %%
df.head(25)
# Out:
#         Category                                             Resume  \
# 0   Data Science  Skills * Programming Languages: Python (pandas...
# 1   Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2   Data Science  Areas of Interest Deep Learning, Control Syste...
# 3   Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4   Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
# 5   Data Science  SKILLS C Basics, IOT, Python, MATLAB, Data Sci...
# 6   Data Science  Skills â¢ Python â¢ Tableau â¢ Data Visuali...
# 7   Data Science  Education Details \r\n B.Tech   Rayat and Bahr...
# 8   Data Science  Personal Skills â¢ Ability to quickly grasp t...
# 9   Data Science  Expertise â Data and Quantitative Analysis â...
# 10  Data Science  Skills * Programming Languages: Python (pandas...
# 11  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 12  Data Science  Areas of Interest Deep Learning, Control Syste...
# 13  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 14  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
# 15  Data Science  SKILLS C Basics, IOT, Python, MATLAB, Data Sci...
# 16  Data Science  Skills â¢ Python â¢ Tableau â¢ Data Visuali...
# 17  Data Science  Education Details \r\n B.Tech   Rayat and Bahr...
# 18  Data Science  Personal Skills â¢ Ability to quickly grasp t...
# 19  Data Science  Expertise â Data and Quantitative Analysis â...
# 20  Data Science  Skills * Programming Languages: Python (pandas...
# 21  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 22  Data Science  Areas of Interest Deep Learning, Control Syste...
# 23  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 24  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
#
#                                   cleaned_resume_data
# 0   skills programming languages python pandas num...
# 1   education details  may 2013 to may 2017 b e ui...
# 2   areas of interest deep learning control system...
# 3   skills  r  python  sap hana  tableau  sap hana...
# 4   education details   mca ymcaust faridabad hary...
# 5   skills c basics iot python matlab data science...
# 6   skills  python  tableau  data visualization  r...
# 7   education details   b tech rayat and bahra ins...
# 8   personal skills  ability to quickly grasp tech...
# 9   expertise  data and quantitative analysis  dec...
# 10  skills programming languages python pandas num...
# 11  education details  may 2013 to may 2017 b e ui...
# 12  areas of interest deep learning control system...
# 13  skills  r  python  sap hana  tableau  sap hana...
# 14  education details   mca ymcaust faridabad hary...
# 15  skills c basics iot python matlab data science...
# 16  skills  python  tableau  data visualization  r...
# 17  education details   b tech rayat and bahra ins...
# 18  personal skills  ability to quickly grasp tech...
# 19  expertise  data and quantitative analysis  dec...
# 20  skills programming languages python pandas num...
# 21  education details  may 2013 to may 2017 b e ui...
# 22  areas of interest deep learning control system...
# 23  skills  r  python  sap hana  tableau  sap hana...
# 24  education details   mca ymcaust faridabad hary...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(stop_words='english')

# %%
X = vectorizer.fit_transform(df['cleaned_resume_data'])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
df['Category_encoded'] = label_encoder.fit_transform(df['Category'])

# %%
df.head()
# Out:
#        Category                                             Resume  \
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
#
#                                  cleaned_resume_data  Category_encoded
# 0  skills programming languages python pandas num...                 6
# 1  education details  may 2013 to may 2017 b e ui...                 6
# 2  areas of interest deep learning control system...                 6
# 3  skills  r  python  sap hana  tableau  sap hana...                 6
# 4  education details   mca ymcaust faridabad hary...                 6

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report , accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split(X, df['Category_encoded'], test_size=0.2, random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb_model = MultinomialNB()

# %%
nb_model.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
y_test_pred = nb_model.predict(x_test)

# %%
print("Accuracy Score:", accuracy_score(y_test, y_test_pred))
# Out:
# Accuracy Score: 0.9637305699481865

# %%
print("Classification Report:\n", classification_report(y_test, y_test_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50         3
#            1       1.00      1.00      1.00         6
#            2       1.00      1.00      1.00         5
#            3       1.00      1.00      1.00         7
#            4       1.00      1.00      1.00         4
#            5       1.00      0.67      0.80         9
#            6       1.00      1.00      1.00         5
#            7       1.00      1.00      1.00         8
#            8       1.00      0.93      0.96        14
#            9       1.00      1.00      1.00         5
#           10       1.00      1.00      1.00         7
#           11       1.00      1.00      1.00         6
#           12       1.00      0.92      0.96        12
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         7
#           15       0.83      1.00      0.91        15
#           16       1.00      1.00      1.00         8
#           17       1.00      1.00      1.00         3
#           18       1.00      1.00      1.00        12
#           19       0.88      1.00      0.93         7
#           20       1.00      1.00      1.00        10
#           21       1.00      1.00      1.00         7
#           22       1.00      1.00      1.00         8
#           23       0.84      1.00      0.91        16
#           24       1.00      1.00      1.00         5
#
#     accuracy                           0.96       193
#    macro avg       0.98      0.95      0.96       193
# weighted avg       0.97      0.96      0.96       193

# %%
training_accuracy=accuracy_score(y_train,y_train_pred)
training_accuracy
# Out:
# 1.0

# %%
import pickle

# %%
with open('tfidf_vectorizer.pkl', 'wb') as file:
    pickle.dump(vectorizer, file)

# %%
with open("naive_bayes.pkl","wb") as f:
    pickle.dump(nb_model,f)

# %%
with open("naive_bayes.pkl","rb") as f:
    m1=pickle.load(f)

# %%
with open("label_encoder.pkl", "wb") as encoder_file:
    pickle.dump(label_encoder, encoder_file)
